# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, linewidth=10)
plt.plot(x, z, linewidth=5)

plt.xlabel('x, y')
plt.xlabel('x, z')

plt.title('Super rad plot')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1, 2)
ax1.plot(x, y)
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label') 
ax1.set_title('Oeoe')

ax2.plot(x, z)
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')
ax2.set_title('Super rad plot')
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1, 2, figsize = (10, 10))
ax1.plot(x, y)
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label') 
ax1.set_title('Oeoe')

ax2.plot(x, z)
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')
ax2.set_title('Super rad plot')
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
import math
figs, [ax1, ax2] = plt.subplots(2, figsize=(10, 6))

ax1.plot(x, x**2, linewidth=10)
ax2.plot(y, math.e**x, linewidth=5)

ax1.set_xlabel('x, y')
ax2.set_xlabel('x, z')

ax1.set_xscale('linear')
ax2.set_xscale('linear')
ax1.set_yscale('log')
ax2.set_yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
fitbit = pd.read_csv('Fitbit2.csv')

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(fitbit.groupby('Months_encoded').mean()['Steps'])
ax1.set_xlabel('Month')     
ax1.set_ylabel('Avg. steps')
ax1.set_xticks(fitbit['Months_encoded'].unique())
ax1.set_title('Avg. steps by month')


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
ax2.bar(fitbit.groupby('Work_or_Weekend').sum().index, fitbit.groupby('Work_or_Weekend').mean()['Steps'])
ax2.set_xlabel('Weekend or Workday')     
ax2.set_ylabel('Avg. steps')
ax2.set_title('Avg. steps during workdays and weekends')
ax2.set_xticks([0,1])
ax2.set_xticklabels(['Work', 'Weekend'])
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, axes = plt.subplots(3, 1,figsize=(6,10))

for col, axe in zip(['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active'], axes):
    axe.scatter(fitbit.groupby(col).mean().index, fitbit.groupby(col).mean()['Steps'])
    axe.grid(axis='both')
    axe.set_xlabel(col)
    axe.set_ylabel('Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv', index_col=0)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude='number').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(3)

for bin_size, axe in zip([10, 20, 50], axes):
    axe.hist(titanic['Age'], bins=bin_size)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Having more bins increase the detail of the plot 
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
import seaborn as snb

# %%
snb.distplot(titanic['Age'], color='orange')

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.bar(titanic.groupby('Gender').count().index, titanic.groupby('Gender').count()['PassengerId'])
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
snb.barplot(titanic.groupby('Gender').count().index, titanic.groupby('Gender').count()['PassengerId'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
snb.barplot(titanic.groupby('Pclass').count().index, titanic.groupby('Pclass').count()['PassengerId'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f223f366358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f223f3669e8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f223f3daef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f223f366e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f223f372400>],
#  'means': []}

# %%
"""
I am using a box plot since it summarizes everything
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The mean is quite low compared to the max and the quartiles also show that the distribution is skewed to the right. Lots
of outliers
"""
# Out:
# '\nThe mean is quite low compared to the max and the quartiles also show that the distribution is skewed to the right. Lots\nof outliers\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
snb.violinplot(titanic['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
We can see a more detailed distribution of the values
"""
# Out:
# '\nWe can see a more detailed distribution of the values\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Fare'],titanic['Age'])

# %%
# Method 2 - seaborn
# your code here
snb.scatterplot(titanic['Fare'],titanic['Age'])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
snb.heatmap(titanic.corr(), cmap="YlGnBu")

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Passenger class is negatively correlated with Fare, Age and Survived, which was expected. The price is higher which means
that older people will afford it more easily and they have better chance of survival since they have priority on the 
lifeboats.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
snb.boxplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
gender = snb.FacetGrid(data=titanic, col='Gender')

gender.map(plt.hist, 'Age')
plt.show()
